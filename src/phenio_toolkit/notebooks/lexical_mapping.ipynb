# %%
import pandas as pd
import sys
import os
import re

# %%
profile = sys.argv[1]
profile = "all"
stopwords = ['abnormally','abnormal','aberrant','variant']
outdir = "../curation/data"
uphenorelease_dir = "../../../upheno-release/"

## IN
upheno_mapping_logical = os.path.join(uphenorelease_dir,"upheno_mapping_logical.csv")
upheno_species_lexical_file = os.path.join(uphenorelease_dir,"upheno_species_lexical.csv")
print(upheno_species_lexical_file)
## OUT
upheno_mapping_all = os.path.join(uphenorelease_dir,"upheno_mapping_all.csv")
upheno_mapping_lexical = os.path.join(uphenorelease_dir,"upheno_mapping_lexical.csv")
upheno_mapping_lexical_template = os.path.join(uphenorelease_dir,"upheno_mapping_lexical_template.csv")
upheno_mapping_problematic = os.path.join(uphenorelease_dir,"upheno_mapping_problematic.csv")
    
## Load lexical data
df = pd.read_csv(upheno_species_lexical_file)
print(df)
df.columns = ['iri','p','label']

## Load logical mappings
dfl1 = pd.read_csv(upheno_mapping_logical)[['p1','p2']]
dfl2 = dfl1.copy()
dfl2.columns = ['p2','p1']
dfl = pd.concat([dfl1, dfl2], ignore_index=True, sort =False)
dfl = dfl.drop_duplicates()
dfl['cat']="logical"

## Prepare dataframe for labels
df_label = df[df['p']=="http://www.w3.org/2000/01/rdf-schema#label"][['iri','label']]
df_label.columns = ['iri','label']
# Out:
# ../../../upheno-release/upheno_species_lexical.csv
#                                                     s  \
# 0       http://purl.obolibrary.org/obo/UPHENO_0001001
# 1       http://purl.obolibrary.org/obo/UPHENO_0001001
# 2       http://purl.obolibrary.org/obo/UPHENO_0001003
# 3       http://purl.obolibrary.org/obo/UPHENO_0001005
# 4           http://purl.obolibrary.org/obo/MP_0001417
# ...                                               ...
# 208112  http://purl.obolibrary.org/obo/UPHENO_0076697
# 208113  http://purl.obolibrary.org/obo/UPHENO_0081568
# 208114  http://purl.obolibrary.org/obo/UPHENO_0002948
# 208115  http://purl.obolibrary.org/obo/UPHENO_0075774
# 208116  http://purl.obolibrary.org/obo/UPHENO_0002848
#
#                                                         p  \
# 0              http://www.w3.org/2000/01/rdf-schema#label
# 1              http://www.w3.org/2000/01/rdf-schema#label
# 2              http://www.w3.org/2000/01/rdf-schema#label
# 3              http://www.w3.org/2000/01/rdf-schema#label
# 4              http://www.w3.org/2000/01/rdf-schema#label
# ...                                                   ...
# 208112  http://www.geneontology.org/formats/oboInOwl#h...
# 208113  http://www.geneontology.org/formats/oboInOwl#h...
# 208114  http://www.geneontology.org/formats/oboInOwl#h...
# 208115  http://www.geneontology.org/formats/oboInOwl#h...
# 208116  http://www.geneontology.org/formats/oboInOwl#h...
#
#                                                    label
# 0                                              phenotype
# 1                                              Phenotype
# 2                           phenotype by ontology source
# 3                  abnormal phenotype by ontology source
# 4         decreased exploration in new environment (MPO)
# ...                                                  ...
# 208112     abnormal morphology of lateral plate mesoderm
# 208113                   abnormal morphology of shoulder
# 208114                      abnormality of immune system
# 208115  abnormality of lymphatic part of lymphoid system
# 208116                         abnormality of lymph node
#
# [208117 rows x 3 columns]

# %%
# Preprocess labels. The most important aspect to this the stopword removal. this is done by matching a stopword
# that means 'abnormal', removing it and then adding the actual prefix 'abnormal'. For example, "cell morphology, aberrant"
# will become 'abnormal cell morphology'. Other than that, most special characters other than space and the ' tick-mark
# Are removed

def apply_stopword(x, stopword):
    if x:
        if stopword in x:
            x = "abnormal "+x.replace(stopword, '')
    return x

UPHENO_PREFIX = "http://purl.obolibrary.org/obo/UPHENO_"

def preprocess_labels(df, stopwords):
    df['label'] = df['label'].astype(str)
    df['label_pp'] = df['label'].str.replace(r"[(][A-Z]+[)]", "")
    df['label_pp'] = df['label_pp'].str.lower()
    df['label_pp'] = df['label_pp'].str.replace(r"[^0-9a-z' ]", "")

    for stopword in stopwords:
        df['label_pp'] = df['label_pp'].apply(lambda x: apply_stopword(x,stopword))

    df['label_pp'] = df['label_pp'].str.strip()
    df['label_pp'] = df['label_pp'].str.replace(r"[ ]+", " ")
    df=df[~df['iri'].astype(str).str.startswith(UPHENO_PREFIX)]
    df=df[df['label_pp']!=""]
    d=df[['iri','label_pp']]
    d.columns=['iri','label']
    d=d.drop_duplicates()
    return d

d = preprocess_labels(df,stopwords)
l = df_label[~df_label['iri'].astype(str).str.startswith(UPHENO_PREFIX)]
print(len(d))
# Out:
# 175815

# %%
dd=d.groupby('label')['iri'].apply(list).to_dict()

# %%
dd
# Out:
# {"'cigarette paper scarring'": ['http://purl.obolibrary.org/obo/HP_0001073'],
#  "'curvilinear profiles' ultrastructurally": ['http://purl.obolibrary.org/obo/HP_0003205'],
#  "'curvilinear profiles' ultrastructurally in cells": ['http://purl.obolibrary.org/obo/HP_0003205'],
#  "'de toni-fanconi-debre' syndrome": ['http://purl.obolibrary.org/obo/HP_0001994'],
#  "'decreased jaw size'": ['http://purl.obolibrary.org/obo/MP_0002639'],
#  "'decreased mandible length'": ['http://purl.obolibrary.org/obo/MP_0004592'],
#  "'decreased maxilla length'": ['http://purl.obolibrary.org/obo/MP_0000097'],
#  "'decreased maxilla size'": ['http://purl.obolibrary.org/obo/MP_0004540'],
#  "'decreased tibia length'": ['http://purl.obolibrary.org/obo/MP_0002764'],
#  "'decreased vertebral body length'": ['http://purl.obolibrary.org/obo/MP_0004706'],
#  "'fingerprint profiles' ultrastructurally in cells": ['http://purl.obolibrary.org/obo/HP_0003208'],
#  "'generalised' tonic-clonic seizure with focal onset": ['http://purl.obolibrary.org/obo/HP_0007334'],
#  "'generalised' tonic-clonic seizure with partial onset": ['http://purl.obolibrary.org/obo/HP_0007334'],
#  "'generalized' tonic-clonic seizure with focal onset": ['http://purl.obolibrary.org/obo/HP_0007334'],
#  "'generalized' tonic-clonic seizure with partial onset": ['http://purl.obolibrary.org/obo/HP_0007334'],
#  "'increased sternum width'": ['http://purl.obolibrary.org/obo/MP_0012279'],
#  "'increased toenail length'": ['http://purl.obolibrary.org/obo/MP_0000583'],
#  "'increased vertebral body length'": ['http://purl.obolibrary.org/obo/MP_0004705'],
#  "'molar tooth sign' on brain imaging'": ['http://purl.obolibrary.org/obo/HP_0002419'],
#  "'molar tooth' sign on imaging": ['http://purl.obolibrary.org/obo/HP_0002419'],
#  "'onion bulb' formations": ['http://purl.obolibrary.org/obo/HP_0003383'],
#  "'rimmed vacuoles' on biopsy": ['http://purl.obolibrary.org/obo/HP_0003805'],
#  "'rimmed' vacuoles on biopsy": ['http://purl.obolibrary.org/obo/HP_0003805'],
#  "'sea blue' histiocytes": ['http://purl.obolibrary.org/obo/HP_0001982'],
#  "'steppage' gait": ['http://purl.obolibrary.org/obo/HP_0003376'],
#  "'tortuous capillaries'": ['http://purl.obolibrary.org/obo/MP_0020331'],
#  "'waddling' gait": ['http://purl.obolibrary.org/obo/HP_0002515'],
#  '1-2 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010704'],
#  '1-2 toe complete cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0005767'],
#  '1-2 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010711'],
#  '1-3 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010706'],
#  '1-3 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0001459'],
#  '1-4 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010707'],
#  '1-4 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010712'],
#  '1-5 finger complete cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0006088'],
#  '1-5 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010708'],
#  '1-5 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010713'],
#  '1-methylhistidinuria': ['http://purl.obolibrary.org/obo/HP_0410315'],
#  '1-minute apgar score of 0 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030927'],
#  '1-minute apgar score of 1 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030928'],
#  '1-minute apgar score of 2 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030929'],
#  '1-minute apgar score of 3 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030930'],
#  '1-minute apgar score of 4 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030931'],
#  '1-minute apgar score of 5 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030932'],
#  '1-minute apgar score of 6 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030933'],
#  '10 pairs of ribs': ['http://purl.obolibrary.org/obo/HP_0030300'],
#  '10 pairs of ribs (hpo)': ['http://purl.obolibrary.org/obo/HP_0030300'],
#  '10-minute apgar score of 0 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033468'],
#  '10-minute apgar score of 1 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033469'],
#  '10-minute apgar score of 2 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033470'],
#  '10-minute apgar score of 3 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033471'],
#  '10-minute apgar score of 4 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033472'],
#  '10-minute apgar score of 5 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033473'],
#  '10-minute apgar score of 6 (hpo)': ['http://purl.obolibrary.org/obo/HP_0033474'],
#  '11 pairs of ribs': ['http://purl.obolibrary.org/obo/HP_0000878'],
#  '11 pairs of ribs (hpo)': ['http://purl.obolibrary.org/obo/HP_0000878'],
#  '11 thoracic vertebrae (hpo)': ['http://purl.obolibrary.org/obo/HP_0030306'],
#  '18s rrna acetylation abolished': ['http://purl.obolibrary.org/obo/FYPO_0005016'],
#  '2 vessel cord': ['http://purl.obolibrary.org/obo/HP_0001195'],
#  '2 vessel umbilical cord': ['http://purl.obolibrary.org/obo/HP_0001195'],
#  '2,2,7-trimethylguanosine cap formation abolished': ['http://purl.obolibrary.org/obo/FYPO_0001173'],
#  '2,8-dihydroxyadenine crystalluria (hpo)': ['http://purl.obolibrary.org/obo/HP_0034279'],
#  '2,8-dihydroxyadenine urinary crystals': ['http://purl.obolibrary.org/obo/HP_0034279'],
#  '2-3 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0001233'],
#  '2-3 syndactyly of feet': ['http://purl.obolibrary.org/obo/HP_0004691'],
#  '2-3 toe cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0005709'],
#  '2-3 toe soft tissue syndactyly': ['http://purl.obolibrary.org/obo/HP_0004691'],
#  '2-3 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0004691'],
#  '2-3 toes syndactyly': ['http://purl.obolibrary.org/obo/HP_0004691'],
#  '2-3-layered lissencephaly (hpo)': ['http://purl.obolibrary.org/obo/HP_0032457'],
#  '2-4 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010709'],
#  '2-4 toe cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0005768'],
#  '2-4 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010714'],
#  '2-5 finger cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0005650'],
#  '2-5 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010692'],
#  '2-5 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010715'],
#  '2-aminoadipic aciduria': ['http://purl.obolibrary.org/obo/HP_0410309'],
#  '2-ethylhydracylic aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0033220'],
#  '2-hydroxyglutarate aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0032278'],
#  '2-methylbutyryl glycinuria (hpo)': ['http://purl.obolibrary.org/obo/HP_0020147'],
#  '2-oxoglutarate dioxygenase activity abolished': ['http://purl.obolibrary.org/obo/FYPO_0004872'],
#  '2-trans,6-trans,10-trans-geranylgeranyl diphosphate absent from cell': ['http://purl.obolibrary.org/obo/FYPO_0002314'],
#  '20s rrna precursor absent from cell (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0007065'],
#  '20s rrna precursor absent from cell during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0007065'],
#  '20s rrna precursor transcripts absent from cell during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0007065'],
#  '22g rna expression reduced (wbp)': ['http://purl.obolibrary.org/obo/WBPhenotype_0002253'],
#  '2nd toe symphalangism': ['http://purl.obolibrary.org/obo/HP_0010353'],
#  '2nd-5th toe middle phalangeal hypoplasia (hpo)': ['http://purl.obolibrary.org/obo/HP_0008083'],
#  "3'-5' dna helicase activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0002101'],
#  "3'-5'-exoribonuclease activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0002064'],
#  "3'-deoxyribose phosphate lyase activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0007229'],
#  '3-4 finger cutaneous syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0011939'],
#  '3-4 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0006097'],
#  '3-4 metacarpal synostosis (hpo)': ['http://purl.obolibrary.org/obo/HP_4000062'],
#  '3-4 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0009779'],
#  '3-5 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010710'],
#  '3-5 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010716'],
#  '3-hydroxydicarboxylic aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0008160'],
#  '3-hydroxyisovaleric aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0033111'],
#  '3-methylglutaconic aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0003535'],
#  '3-methylglutaconicaciduria': ['http://purl.obolibrary.org/obo/HP_0003535'],
#  '3-methylglutaric aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0003344'],
#  '3-methylglutaricaciduria': ['http://purl.obolibrary.org/obo/HP_0003344'],
#  '3-methylhistidinuria': ['http://purl.obolibrary.org/obo/HP_0410317'],
#  '3rd paa dilation': ['http://purl.obolibrary.org/obo/MP_0030338'],
#  '3rd pharyngeal arch artery dilation': ['http://purl.obolibrary.org/obo/MP_0030338'],
#  '3rd toe clinodactyly': ['http://purl.obolibrary.org/obo/HP_0008115'],
#  '3rd ventricle dilation': ['http://purl.obolibrary.org/obo/MP_0000827'],
#  '4,6-o-[(1r)-1-carboxyethylidene]-d-galactose absent from cell': ['http://purl.obolibrary.org/obo/FYPO_0002123'],
#  '4,6-pyruvylated d-galactose absent from cell': ['http://purl.obolibrary.org/obo/FYPO_0002123'],
#  '4-5 finger syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0010705'],
#  '4-5 metacarpal synostosis (hpo)': ['http://purl.obolibrary.org/obo/HP_0005867'],
#  '4-5 toe syndactyly (hpo)': ['http://purl.obolibrary.org/obo/HP_0004692'],
#  '4-hydroxyphenylacetic aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0003607'],
#  '4-hydroxyphenylpyruvic aciduria (hpo)': ['http://purl.obolibrary.org/obo/HP_0003161'],
#  '4-layered lissencephaly (hpo)': ['http://purl.obolibrary.org/obo/HP_0006818'],
#  '46,xy gonadal dysgenesis': ['http://purl.obolibrary.org/obo/HP_0008668'],
#  '4th finger camptodactyly': ['http://purl.obolibrary.org/obo/HP_0009276'],
#  '4th ventricle dilation': ['http://purl.obolibrary.org/obo/MP_0000829'],
#  '5 fu resistant': ['http://purl.obolibrary.org/obo/WBPhenotype_0001649'],
#  "5' deoxyribonuclease (pyrimidine dimer) activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0004029'],
#  "5'-3' dna helicase activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0003818'],
#  "5'-3' dna/rna helicase activity abolished": ['http://purl.obolibrary.org/obo/FYPO_0006649'],
#  '5-minute apgar score of 0 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030920'],
#  '5-minute apgar score of 1 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030921'],
#  '5-minute apgar score of 2 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030922'],
#  '5-minute apgar score of 3 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030923'],
#  '5-minute apgar score of 4 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030924'],
#  '5-minute apgar score of 5 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030925'],
#  '5-minute apgar score of 6 (hpo)': ['http://purl.obolibrary.org/obo/HP_0030926'],
#  '5-oxoprolinase deficiency': ['http://purl.obolibrary.org/obo/HP_0040142'],
#  '5th finger middle phalangeal hypoplasia': ['http://purl.obolibrary.org/obo/HP_0004220'],
#  '6 long bones of hand': ['http://purl.obolibrary.org/obo/HP_0001501'],
#  '6 metacarpals (hpo)': ['http://purl.obolibrary.org/obo/HP_0001501'],
#  '6-layered lissencephaly (hpo)': ['http://purl.obolibrary.org/obo/HP_0032475'],
#  '7-methylguanosine cap hypermethylation abolished': ['http://purl.obolibrary.org/obo/FYPO_0001173'],
#  '7-methylguanosine cap hypermethylation abolished during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0001173'],
#  'a phenotype in which a specific cellular process is decreased during prophase i of the  the meiotic cell cycle.': ['http://purl.obolibrary.org/obo/FYPO_0007978'],
#  'a severe pyogenic infection of the epidural space': ['http://purl.obolibrary.org/obo/HP_0033181'],
#  'aa amyloidosis (hpo)': ['http://purl.obolibrary.org/obo/HP_4000041'],
#  'aa amyloidosis (mpo)': ['http://purl.obolibrary.org/obo/MP_0021146'],
#  'aabsent lpcs': ['http://purl.obolibrary.org/obo/MP_0010041'],
#  'aba abp division axis defective early emb (wbp)': ['http://purl.obolibrary.org/obo/WBPhenotype_0001134'],
#  'aba abp ems synchronous division early emb (wbp)': ['http://purl.obolibrary.org/obo/WBPhenotype_0001124'],
#  'abamectin resistant (wbp)': ['http://purl.obolibrary.org/obo/WBPhenotype_0002048'],
#  'abamectin sensitive (wbp)': ['http://purl.obolibrary.org/obo/WBPhenotype_0002050'],
#  'abasia (hpo)': ['http://purl.obolibrary.org/obo/HP_0012651'],
#  'abdomen closed contusion (mpo)': ['http://purl.obolibrary.org/obo/MP_0013054'],
#  'abdomen open abrasion (mpo)': ['http://purl.obolibrary.org/obo/MP_0013049'],
#  'abdomen open avulsion (mpo)': ['http://purl.obolibrary.org/obo/MP_0013050'],
#  'abdomen open incision (mpo)': ['http://purl.obolibrary.org/obo/MP_0013051'],
#  'abdomen open laceration (mpo)': ['http://purl.obolibrary.org/obo/MP_0013052'],
#  'abdomen open puncture (mpo)': ['http://purl.obolibrary.org/obo/MP_0013053'],
#  'abdomen swellings (mpo)': ['http://purl.obolibrary.org/obo/MP_0013119'],
#  'abdomen wound (mpo)': ['http://purl.obolibrary.org/obo/MP_0013048'],
#  'abdominal adhesions (hpo)': ['http://purl.obolibrary.org/obo/HP_0033134'],
#  'abdominal aorta aneurysm (mpo)': ['http://purl.obolibrary.org/obo/MP_0010659'],
#  'abdominal aorta coarctation (mpo)': ['http://purl.obolibrary.org/obo/MP_0010525'],
#  'abdominal aortic aneurysm (hpo)': ['http://purl.obolibrary.org/obo/HP_0005112'],
#  'abdominal aortic calcification (hpo)': ['http://purl.obolibrary.org/obo/HP_0031313'],
#  'abdominal aortic dissection (hpo)': ['http://purl.obolibrary.org/obo/HP_0033311'],
#  'abdominal aseptic abscess (hpo)': ['http://purl.obolibrary.org/obo/HP_0025181'],
#  'abdominal aura': ['http://purl.obolibrary.org/obo/HP_0011159'],
#  'abdominal bloating': ['http://purl.obolibrary.org/obo/HP_0003270'],
#  'abdominal colic (hpo)': ['http://purl.obolibrary.org/obo/HP_0011848'],
#  'abdominal cramps (hpo)': ['http://purl.obolibrary.org/obo/HP_0032155'],
#  'abdominal distension': ['http://purl.obolibrary.org/obo/HP_0003270'],
#  'abdominal distention (hpo)': ['http://purl.obolibrary.org/obo/HP_0003270'],
#  'abdominal ectopia cordis (hpo)': ['http://purl.obolibrary.org/obo/HP_0011582'],
#  'abdominal guarding (hpo)': ['http://purl.obolibrary.org/obo/HP_0032546'],
#  'abdominal heterotaxy': ['http://purl.obolibrary.org/obo/MP_0011250'],
#  'abdominal mass (hpo)': ['http://purl.obolibrary.org/obo/HP_0031500'],
#  'abdominal muscular hypoplasia': ['http://purl.obolibrary.org/obo/HP_0005247'],
#  'abdominal obesity': ['http://purl.obolibrary.org/obo/HP_0012743'],
#  'abdominal obesity (hpo)': ['http://purl.obolibrary.org/obo/HP_0012743'],
#  'abdominal pain': ['http://purl.obolibrary.org/obo/HP_0002027'],
#  'abdominal pain (hpo)': ['http://purl.obolibrary.org/obo/HP_0002027'],
#  'abdominal protuberance': ['http://purl.obolibrary.org/obo/HP_0001538'],
#  'abdominal reflex absent': ['http://purl.obolibrary.org/obo/HP_0031827'],
#  'abdominal rigidity (hpo)': ['http://purl.obolibrary.org/obo/HP_0032545'],
#  'abdominal situs ambiguous': ['http://purl.obolibrary.org/obo/MP_0011250'],
#  'abdominal situs ambiguus (hpo)': ['http://purl.obolibrary.org/obo/HP_0031565'],
#  'abdominal situs ambiguus (mpo)': ['http://purl.obolibrary.org/obo/MP_0011250'],
#  'abdominal situs inversus (hpo)': ['http://purl.obolibrary.org/obo/HP_0003363'],
#  'abdominal situs inversus (mpo)': ['http://purl.obolibrary.org/obo/MP_0011249'],
#  'abdominal swelling': ['http://purl.obolibrary.org/obo/HP_0003270'],
#  'abdominal symptom (hpo)': ['http://purl.obolibrary.org/obo/HP_0011458'],
#  'abdominal testes': ['http://purl.obolibrary.org/obo/MP_0002286'],
#  'abdominal wall defect': ['http://purl.obolibrary.org/obo/HP_0010866'],
#  'abdominal wall defect (hpo)': ['http://purl.obolibrary.org/obo/HP_0010866'],
#  'abdominal wall muscle weakness (hpo)': ['http://purl.obolibrary.org/obo/HP_0009023'],
#  'abdominoschisis': ['http://purl.obolibrary.org/obo/MP_0000757'],
#  'abducens nerve dysplasia': ['http://purl.obolibrary.org/obo/MP_0001070'],
#  'abducens nerve palsy': ['http://purl.obolibrary.org/obo/HP_0006897'],
#  'abducens nerve paralysis': ['http://purl.obolibrary.org/obo/HP_0006897'],
#  'abducens nerve paresis': ['http://purl.obolibrary.org/obo/HP_0006897'],
#  'abducens palsy (hpo)': ['http://purl.obolibrary.org/obo/HP_0006897'],
#  'abducted thumb': ['http://purl.obolibrary.org/obo/HP_0001234'],
#  'abetalipoproteinemia (hpo)': ['http://purl.obolibrary.org/obo/HP_0008181'],
#  'ablepharia': ['http://purl.obolibrary.org/obo/MP_0001341'],
#  'ablepharon': ['http://purl.obolibrary.org/obo/MP_0001341'],
#  'ablepharon (hpo)': ['http://purl.obolibrary.org/obo/HP_0011224'],
#  'ablepharon of eyelid': ['http://purl.obolibrary.org/obo/HP_0011224'],
#  'abnomal kidney cortical medullary ray morphology': ['http://purl.obolibrary.org/obo/MP_0011347'],
#  'abnoormal suprarenal capsule development': ['http://purl.obolibrary.org/obo/MP_0013310'],
#  'abnormal': ['http://purl.obolibrary.org/obo/WBPhenotype_0000886'],
#  'abnormal   abaxially mislocalized anterior foregut (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115768'],
#  'abnormal   abaxially mislocalized cardiac mesoderm (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115447'],
#  'abnormal   anterioralized embryo (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115383'],
#  'abnormal   anteriorly mislocalised eye (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115419'],
#  'abnormal   anteriorly mislocalised skeletal muscle (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115411'],
#  'abnormal   anteriorly mislocalised somite (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115345'],
#  'abnormal   aplastic growth of hindlimb bud (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115604'],
#  'abnormal   aplastic growth of regenerating tail (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115688'],
#  'abnormal   arrested cell cycle progression (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0000407'],
#  'abnormal   arrested cell cycle progression during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0000407'],
#  'abnormal   arrested first meiotic nuclear division': ['http://purl.obolibrary.org/obo/FYPO_0002817'],
#  'abnormal   arrested first meiotic nuclear division with four spindle pole bodies': ['http://purl.obolibrary.org/obo/FYPO_0004584'],
#  'abnormal   arrested meiosis (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0000475'],
#  'abnormal   arrested meiosis i (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0002817'],
#  'abnormal   arrested meiosis i with duplicated spindle pole bodies': ['http://purl.obolibrary.org/obo/FYPO_0004584'],
#  'abnormal   arrested meiosis i with four spbs': ['http://purl.obolibrary.org/obo/FYPO_0004584'],
#  'abnormal   arrested meiosis i with four spindle pole bodies (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0004584'],
#  'abnormal   arrested meiotic cell cycle (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0002224'],
#  'abnormal   arrested meiotic nuclear division': ['http://purl.obolibrary.org/obo/FYPO_0000475'],
#  'abnormal   arrested mitotic cell cycle': ['http://purl.obolibrary.org/obo/FYPO_0000502'],
#  'abnormal   arrested mitotic cell cycle progression (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0000502'],
#  'abnormal   arrested mitotic cell cycle progression during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0000502'],
#  'abnormal   asymmetric gamma-tubulin complex localization to single mitotic spindle pole body': ['http://purl.obolibrary.org/obo/FYPO_0005381'],
#  'abnormal   bending anterior neural tube': ['http://purl.obolibrary.org/obo/XPO_0103701'],
#  'abnormal   bending anterior-posterior axis': ['http://purl.obolibrary.org/obo/XPO_0103699'],
#  'abnormal   bending dorsal trunk': ['http://purl.obolibrary.org/obo/XPO_0103704'],
#  'abnormal   bending humerus': ['http://purl.obolibrary.org/obo/XPO_0103700'],
#  'abnormal   bending left-right axis': ['http://purl.obolibrary.org/obo/XPO_0103705'],
#  'abnormal   bending tail': ['http://purl.obolibrary.org/obo/XPO_0103702'],
#  'abnormal   bent metatarsus (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115636'],
#  'abnormal   broad great toes': ['http://purl.obolibrary.org/obo/HP_0010055'],
#  'abnormal   close eyes': ['http://purl.obolibrary.org/obo/MP_0006197',
#   'http://purl.obolibrary.org/obo/HP_0000601'],
#  'abnormal   closed or absent vagina': ['http://purl.obolibrary.org/obo/HP_0000148'],
#  'abnormal   closed posterior neural tube': ['http://purl.obolibrary.org/obo/XPO_0103470'],
#  'abnormal   clustered protein localisation to nuclear envelope': ['http://purl.obolibrary.org/obo/FYPO_0007771'],
#  'abnormal   clustered protein localization to nuclear envelope (fypo)': ['http://purl.obolibrary.org/obo/FYPO_0007771'],
#  'abnormal   clustered protein localization to nuclear envelope during vegetative growth': ['http://purl.obolibrary.org/obo/FYPO_0007771'],
#  'abnormal   coiled small intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133341'],
#  'abnormal   decreased adhesivity of prechordal plate (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115362'],
#  'abnormal   decreased coiling of external coil of the small intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133351'],
#  'abnormal   decreased coiling of foregut (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115445'],
#  'abnormal   decreased coiling of internal coil of the small intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133352'],
#  'abnormal   decreased coiling of proximal tubule (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115761'],
#  'abnormal   decreased coiling of small intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133350'],
#  'abnormal   decreased diameter of mullerian duct (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115474'],
#  'abnormal   decreased height of anterior neural fold (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115463'],
#  'abnormal   decreased length of alimentary system (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115388'],
#  'abnormal   decreased length of hindgut (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115376'],
#  'abnormal   decreased length of hindlimb digit 1 in regenerating tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115988'],
#  'abnormal   decreased length of hindlimb digit 2 in regenerating tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115989'],
#  'abnormal   decreased length of hindlimb digit 3 in regenerating tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115990'],
#  'abnormal   decreased length of hindlimb digit 4 in regenerating tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115991'],
#  'abnormal   decreased length of hindlimb digit 5 in regenerating tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115992'],
#  'abnormal   decreased length of intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115397'],
#  'abnormal   decreased mass of chondrocranium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115588'],
#  'abnormal   decreased mobility of melanoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115758'],
#  'abnormal   decreased mobility of migratory neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115664'],
#  'abnormal   decreased mobility of non-neural ectoderm (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115669'],
#  'abnormal   decreased number of abdominal myoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131290'],
#  'abnormal   decreased number of absorptive cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131348'],
#  'abnormal   decreased number of acid secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131248'],
#  'abnormal   decreased number of acinar cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131357'],
#  'abnormal   decreased number of adult thrombocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131271'],
#  'abnormal   decreased number of afferent neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131375'],
#  'abnormal   decreased number of alkali secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131300'],
#  'abnormal   decreased number of alpha cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131198'],
#  'abnormal   decreased number of amacrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131331'],
#  'abnormal   decreased number of angioblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131338'],
#  'abnormal   decreased number of animal blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131235'],
#  'abnormal   decreased number of anterior crista (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131330'],
#  'abnormal   decreased number of apoptotic cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131351'],
#  'abnormal   decreased number of ascending interneuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131225'],
#  'abnormal   decreased number of astrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131286'],
#  'abnormal   decreased number of auditory hair cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131259'],
#  'abnormal   decreased number of b cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131382'],
#  'abnormal   decreased number of barrier cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131352'],
#  'abnormal   decreased number of barrier epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131389'],
#  'abnormal   decreased number of beta cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131190'],
#  'abnormal   decreased number of bipolar neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131355'],
#  'abnormal   decreased number of bipolar neuron in the retinal inner plexiform layer (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141537'],
#  'abnormal   decreased number of blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131208'],
#  'abnormal   decreased number of blastomere d1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131344'],
#  'abnormal   decreased number of blastomere d1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131303'],
#  'abnormal   decreased number of blastomere d1.1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131349'],
#  'abnormal   decreased number of blastomere d1.1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131334'],
#  'abnormal   decreased number of blastomere d1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131236'],
#  'abnormal   decreased number of blastomere d1.2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131393'],
#  'abnormal   decreased number of blastomere d1.2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131373'],
#  'abnormal   decreased number of blastomere d2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131273'],
#  'abnormal   decreased number of blastomere d2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131206'],
#  'abnormal   decreased number of blastomere d2.1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131385'],
#  'abnormal   decreased number of blastomere d2.1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131312'],
#  'abnormal   decreased number of blastomere d2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131264'],
#  'abnormal   decreased number of blastomere d2.2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131392'],
#  'abnormal   decreased number of blastomere d2.2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131289'],
#  'abnormal   decreased number of blastomere v1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131214'],
#  'abnormal   decreased number of blastomere v1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131249'],
#  'abnormal   decreased number of blastomere v1.1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131360'],
#  'abnormal   decreased number of blastomere v1.1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131365'],
#  'abnormal   decreased number of blastomere v1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131370'],
#  'abnormal   decreased number of blastomere v1.2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131251'],
#  'abnormal   decreased number of blastomere v1.2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131239'],
#  'abnormal   decreased number of blastomere v2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131245'],
#  'abnormal   decreased number of blastomere v2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131261'],
#  'abnormal   decreased number of blastomere v2.1.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131376'],
#  'abnormal   decreased number of blastomere v2.1.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131242'],
#  'abnormal   decreased number of blastomere v2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131325'],
#  'abnormal   decreased number of blastomere v2.2.1 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131272'],
#  'abnormal   decreased number of blastomere v2.2.2 (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131378'],
#  'abnormal   decreased number of bone element in the forelimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141538'],
#  'abnormal   decreased number of bone element in the forelimb digit (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103831'],
#  'abnormal   decreased number of bone element in the hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141539'],
#  'abnormal   decreased number of bone element in the hindlimb digit (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103837'],
#  'abnormal   decreased number of bottle cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131265'],
#  'abnormal   decreased number of cardiac myocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131311'],
#  'abnormal   decreased number of cardiac progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131317'],
#  'abnormal   decreased number of cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131180'],
#  'abnormal   decreased number of cell in the proximal tubule (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103654'],
#  'abnormal   decreased number of cementoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131383'],
#  'abnormal   decreased number of ceratohyal (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103885'],
#  'abnormal   decreased number of chondroblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131346'],
#  'abnormal   decreased number of chondrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131185'],
#  'abnormal   decreased number of ciliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131205'],
#  'abnormal   decreased number of ciliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103886'],
#  'abnormal   decreased number of ciliated non-epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131326'],
#  'abnormal   decreased number of cilium in the alimentary system (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131437'],
#  'abnormal   decreased number of cilium in the auditory hair cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131435'],
#  'abnormal   decreased number of cilium in the brain (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131429'],
#  'abnormal   decreased number of cilium in the ciliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133471'],
#  'abnormal   decreased number of cilium in the ciliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103643'],
#  'abnormal   decreased number of cilium in the ciliated non-epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133473'],
#  'abnormal   decreased number of cilium in the esophagus (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131439'],
#  'abnormal   decreased number of cilium in the floor plate (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131428'],
#  'abnormal   decreased number of cilium in the lateral line (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131436'],
#  'abnormal   decreased number of cilium in the left-right organizer (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131426'],
#  'abnormal   decreased number of cilium in the monociliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133472'],
#  'abnormal   decreased number of cilium in the monociliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133474'],
#  'abnormal   decreased number of cilium in the mucociliary epithelium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131430'],
#  'abnormal   decreased number of cilium in the multiciliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103644'],
#  'abnormal   decreased number of cilium in the multiciliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0133475'],
#  'abnormal   decreased number of cilium in the neural progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131427'],
#  'abnormal   decreased number of cilium in the olfactory pit (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131434'],
#  'abnormal   decreased number of cilium in the pronephric kidney (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131431'],
#  'abnormal   decreased number of cilium in the pronephric nephrostome (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131432'],
#  'abnormal   decreased number of cilium in the proximal tubule (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131433'],
#  'abnormal   decreased number of cilium in the stomach (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131438'],
#  'abnormal   decreased number of circulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131222'],
#  'abnormal   decreased number of claw (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103888'],
#  'abnormal   decreased number of claw in the regenerating hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141535'],
#  'abnormal   decreased number of commissural interneuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131380'],
#  'abnormal   decreased number of delta cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131306'],
#  'abnormal   decreased number of descending interneuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131284'],
#  'abnormal   decreased number of digestive enzyme secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131255'],
#  'abnormal   decreased number of digit-joint region in the regenerating forelimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103833'],
#  'abnormal   decreased number of digit-joint region in the regenerating hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103839'],
#  'abnormal   decreased number of dorsal animal hemisphere blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131234'],
#  'abnormal   decreased number of dorsal vegetal hemisphere blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131207'],
#  'abnormal   decreased number of dorsolateral ascending neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131250'],
#  'abnormal   decreased number of dorsolateral commissural neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131321'],
#  'abnormal   decreased number of early embryonic cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131184'],
#  'abnormal   decreased number of ectodermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131299'],
#  'abnormal   decreased number of efferent neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131368'],
#  'abnormal   decreased number of egg (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131227'],
#  'abnormal   decreased number of electrically active cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131371'],
#  'abnormal   decreased number of embryonic thrombocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131181'],
#  'abnormal   decreased number of endocrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131196'],
#  'abnormal   decreased number of endodermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131390'],
#  'abnormal   decreased number of endothelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131305'],
#  'abnormal   decreased number of enteric neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131391'],
#  'abnormal   decreased number of enteroendocrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131191'],
#  'abnormal   decreased number of epicardial precursor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131260'],
#  'abnormal   decreased number of epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131257'],
#  'abnormal   decreased number of epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131194'],
#  'abnormal   decreased number of epsilon cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131267'],
#  'abnormal   decreased number of erythroid cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131337'],
#  'abnormal   decreased number of exocrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131314'],
#  'abnormal   decreased number of eye photoreceptor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131256'],
#  'abnormal   decreased number of fibroblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131323'],
#  'abnormal   decreased number of filamentous actin in the blastocoel roof (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103646'],
#  'abnormal   decreased number of filopodium in the dermatome (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103645'],
#  'abnormal   decreased number of follicle cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131395'],
#  'abnormal   decreased number of foot (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103595'],
#  'abnormal   decreased number of forelimb digit (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103584'],
#  'abnormal   decreased number of forelimb digit in the regenerating forelimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103832'],
#  'abnormal   decreased number of gamete (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131228'],
#  'abnormal   decreased number of gamma cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131342'],
#  'abnormal   decreased number of gastrula cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131266'],
#  'abnormal   decreased number of germ cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131202'],
#  'abnormal   decreased number of glial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131217'],
#  'abnormal   decreased number of glomerular epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131263'],
#  'abnormal   decreased number of glomerular mesangial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131203'],
#  'abnormal   decreased number of goblet cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131193'],
#  'abnormal   decreased number of granule cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131246'],
#  'abnormal   decreased number of hatching gland cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131345'],
#  'abnormal   decreased number of hemangioblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131359'],
#  'abnormal   decreased number of hematopoietic stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131188'],
#  'abnormal   decreased number of hepato-pancreatic progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131197'],
#  'abnormal   decreased number of hepatocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131287'],
#  'abnormal   decreased number of hindlimb digit (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103589'],
#  'abnormal   decreased number of hindlimb digit in the regenerating hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103838'],
#  'abnormal   decreased number of horizontal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131233'],
#  'abnormal   decreased number of interneuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131226'],
#  'abnormal   decreased number of intersomitic neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131253'],
#  'abnormal   decreased number of interstitial cell of leydig (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131336'],
#  'abnormal   decreased number of intestinal stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131310'],
#  'abnormal   decreased number of ionocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131232'],
#  'abnormal   decreased number of ionocyte, alpha subtype (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131231'],
#  'abnormal   decreased number of ionocyte, beta subtype (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131366'],
#  'abnormal   decreased number of iridophore (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131302'],
#  'abnormal   decreased number of keratin accumulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131278'],
#  'abnormal   decreased number of keratinocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131277'],
#  'abnormal   decreased number of lateral crista (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131339'],
#  'abnormal   decreased number of left blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131288'],
#  'abnormal   decreased number of left-dorsal blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131384'],
#  'abnormal   decreased number of left-ventral blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131397'],
#  'abnormal   decreased number of leydig cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131329'],
#  'abnormal   decreased number of ligament cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131333'],
#  'abnormal   decreased number of lymphoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141493'],
#  'abnormal   decreased number of lymphocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131212'],
#  'abnormal   decreased number of macrophage (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131356'],
#  'abnormal   decreased number of mauthner cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131377'],
#  'abnormal   decreased number of melanoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131297'],
#  'abnormal   decreased number of melanophore (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103597'],
#  'abnormal   decreased number of melanophore in the dorsal fin (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141395'],
#  'abnormal   decreased number of melanophore in the epidermis (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141396'],
#  'abnormal   decreased number of melanophore in the eye (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141397'],
#  'abnormal   decreased number of melanophore in the head (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141399'],
#  'abnormal   decreased number of melanophore in the optic nerve (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141398'],
#  'abnormal   decreased number of melanophore in the optic stalk (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141400'],
#  'abnormal   decreased number of melanophore in the retinal pigmented epithelium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141394'],
#  'abnormal   decreased number of melanophore in the tail (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130956'],
#  'abnormal   decreased number of melanophore in the trunk region (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103649'],
#  'abnormal   decreased number of melanotrope (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131254'],
#  'abnormal   decreased number of merkel cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131195'],
#  'abnormal   decreased number of mesenchymal stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131244'],
#  'abnormal   decreased number of mesodermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131324'],
#  'abnormal   decreased number of metacarpus in the regenerating forelimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103834'],
#  'abnormal   decreased number of metatarsus (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103889'],
#  'abnormal   decreased number of microglial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131332'],
#  'abnormal   decreased number of migrating macrophage (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131386'],
#  'abnormal   decreased number of migrating myoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131285'],
#  'abnormal   decreased number of migrating neuroblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131241'],
#  'abnormal   decreased number of migratory neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131262'],
#  'abnormal   decreased number of migratory neural crest cell in the trunk (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130958'],
#  'abnormal   decreased number of migratory trunk neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131388'],
#  'abnormal   decreased number of mitotic cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131307'],
#  'abnormal   decreased number of mitral cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131258'],
#  'abnormal   decreased number of monociliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131276'],
#  'abnormal   decreased number of monociliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131387'],
#  'abnormal   decreased number of morula cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131183'],
#  'abnormal   decreased number of motor neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131318'],
#  'abnormal   decreased number of mucus secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131292'],
#  'abnormal   decreased number of muller cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131309'],
#  'abnormal   decreased number of multiciliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131316'],
#  'abnormal   decreased number of multiciliated cell precursor (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131354'],
#  'abnormal   decreased number of multiciliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131374'],
#  'abnormal   decreased number of muscle in the forelimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141533'],
#  'abnormal   decreased number of muscle in the hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141534'],
#  'abnormal   decreased number of myelin accumulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131347'],
#  'abnormal   decreased number of myeloid cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131291'],
#  'abnormal   decreased number of myoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131283'],
#  'abnormal   decreased number of myocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131268'],
#  'abnormal   decreased number of natural killer cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131211'],
#  'abnormal   decreased number of neural progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131192'],
#  'abnormal   decreased number of neural progenitor cell in the optic tectum (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103652'],
#  'abnormal   decreased number of neural stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131230'],
#  'abnormal   decreased number of neuroendocrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131340'],
#  'abnormal   decreased number of neuromast mantle cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131215'],
#  'abnormal   decreased number of neuromast support cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131315'],
#  'abnormal   decreased number of neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131186'],
#  'abnormal   decreased number of neuron in the optic tectum (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103653'],
#  'abnormal   decreased number of neutrophil (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131381'],
#  'abnormal   decreased number of non-ciliated epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131274'],
#  'abnormal   decreased number of non-cililated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131294'],
#  'abnormal   decreased number of nucleate erythrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131247'],
#  'abnormal   decreased number of olfactory epithelial support cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131280'],
#  'abnormal   decreased number of olfactory sensory neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131362'],
#  'abnormal   decreased number of oligodendrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131341'],
#  'abnormal   decreased number of oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131213'],
#  'abnormal   decreased number of osteoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131279'],
#  'abnormal   decreased number of oxygen accumulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131308'],
#  'abnormal   decreased number of paracrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131328'],
#  'abnormal   decreased number of perichondrial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131295'],
#  'abnormal   decreased number of pericyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131204'],
# ...
#  'abnormal   increased number of migrating neuroblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131025'],
#  'abnormal   increased number of migratory neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131046'],
#  'abnormal   increased number of migratory trunk neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131170'],
#  'abnormal   increased number of mitotic cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131089'],
#  'abnormal   increased number of mitral cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131042'],
#  'abnormal   increased number of monociliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131059'],
#  'abnormal   increased number of monociliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131169'],
#  'abnormal   increased number of morula cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130967'],
#  'abnormal   increased number of motor neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131100'],
#  'abnormal   increased number of mucus secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131075'],
#  'abnormal   increased number of muller cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131091'],
#  'abnormal   increased number of multiciliated cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131098'],
#  'abnormal   increased number of multiciliated cell precursor (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131136'],
#  'abnormal   increased number of multiciliated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131156'],
#  'abnormal   increased number of myelin accumulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131130'],
#  'abnormal   increased number of myeloid cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131074'],
#  'abnormal   increased number of myoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131066'],
#  'abnormal   increased number of myocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131052'],
#  'abnormal   increased number of natural killer cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130995'],
#  'abnormal   increased number of neural progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130976'],
#  'abnormal   increased number of neural progenitor cell in the optic tectum (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103404'],
#  'abnormal   increased number of neural stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131014'],
#  'abnormal   increased number of neuroendocrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131123'],
#  'abnormal   increased number of neuromast mantle cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130999'],
#  'abnormal   increased number of neuromast support cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131097'],
#  'abnormal   increased number of neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130970'],
#  'abnormal   increased number of neuron in the optic tectum (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103405'],
#  'abnormal   increased number of neutrophil (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131163'],
#  'abnormal   increased number of non-ciliated epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103638'],
#  'abnormal   increased number of non-cililated epidermal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131077'],
#  'abnormal   increased number of nucleate erythrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131031'],
#  'abnormal   increased number of olfactory epithelial support cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131063'],
#  'abnormal   increased number of olfactory sensory neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131144'],
#  'abnormal   increased number of oligodendrocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131124'],
#  'abnormal   increased number of oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130997'],
#  'abnormal   increased number of osteoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131062'],
#  'abnormal   increased number of oxygen accumulating cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131090'],
#  'abnormal   increased number of paracrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131110'],
#  'abnormal   increased number of perichondrial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131078'],
#  'abnormal   increased number of pericyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130988'],
#  'abnormal   increased number of pial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131649'],
#  'abnormal   increased number of pigment cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130983'],
#  'abnormal   increased number of podocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131065'],
#  'abnormal   increased number of polar body (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131145'],
#  'abnormal   increased number of posterior crista (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130993'],
#  'abnormal   increased number of postmigratory neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131021'],
#  'abnormal   increased number of premigratory neural crest cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130971'],
#  'abnormal   increased number of primary oogonium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131086'],
#  'abnormal   increased number of primary spermatogonium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131149'],
#  'abnormal   increased number of primordial germ cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131053'],
#  'abnormal   increased number of proepicardium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131004'],
#  'abnormal   increased number of proximal tubule (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103630'],
#  'abnormal   increased number of radial glial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131000'],
#  'abnormal   increased number of retinal cone cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131140'],
#  'abnormal   increased number of retinal ganglion cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131111'],
#  'abnormal   increased number of retinal progenitor cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130984'],
#  'abnormal   increased number of retinal rod cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131146'],
#  'abnormal   increased number of retinal stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131126'],
#  'abnormal   increased number of right blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131133'],
#  'abnormal   increased number of right-dorsal blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131104'],
#  'abnormal   increased number of right-ventral blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131076'],
#  'abnormal   increased number of rohon-beard neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131154'],
#  'abnormal   increased number of schwann cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131095'],
#  'abnormal   increased number of secondary myofiber (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131058'],
#  'abnormal   increased number of secondary oogonium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130985'],
#  'abnormal   increased number of secondary spermatogonium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131002'],
#  'abnormal   increased number of secretory epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131176'],
#  'abnormal   increased number of sensory epithelial cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130994'],
#  'abnormal   increased number of skeletal muscle satellite cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131008'],
#  'abnormal   increased number of skeletal myocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131079'],
#  'abnormal   increased number of small secretory cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131161'],
#  'abnormal   increased number of smooth muscle myocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131109'],
#  'abnormal   increased number of somatic stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131080'],
#  'abnormal   increased number of spermatid (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131007'],
#  'abnormal   increased number of spermatocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131064'],
#  'abnormal   increased number of spermatozoon (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131135'],
#  'abnormal   increased number of spike in the regenerating hindlimb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0141546'],
#  'abnormal   increased number of spinal neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131102'],
#  'abnormal   increased number of stage i oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131143'],
#  'abnormal   increased number of stage ii oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131118'],
#  'abnormal   increased number of stage iii oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131036'],
#  'abnormal   increased number of stage iv oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131178'],
#  'abnormal   increased number of stage v oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131003'],
#  'abnormal   increased number of stage vi oocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131151'],
#  'abnormal   increased number of stem cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130973'],
#  'abnormal   increased number of stromal cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131101'],
#  'abnormal   increased number of t cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131013'],
#  'abnormal   increased number of tendon fibroblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131083'],
#  'abnormal   increased number of thrombocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0130966'],
#  'abnormal   increased number of thymocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131005'],
#  'abnormal   increased number of vacuole in the spermatozoon (xpo)': ['http://purl.obolibrary.org/obo/XPO_0103414'],
#  'abnormal   increased number of vegetal blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131022'],
#  'abnormal   increased number of ventral animal hemisphere blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131024'],
#  'abnormal   increased number of ventral vegetal hemisphere blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131027'],
#  'abnormal   increased number of xanthophore (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131054'],
#  'abnormal   increased variability of size of cell in endoderm (xpo)': ['http://purl.obolibrary.org/obo/XPO_0116091'],
#  'abnormal   increased volume of blastocoel (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115457'],
#  'abnormal   increased volume of brain (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115308'],
#  'abnormal   increased volume of heart (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115351'],
#  'abnormal   indented hip sockets': ['http://purl.obolibrary.org/obo/HP_0003179'],
#  'abnormal   inverted external coil of the small intestine (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115766'],
#  'abnormal   inverted heart (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115353'],
#  'abnormal   inverted hindlimb zeugopod (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115721'],
#  'abnormal   irregular spatial pattern of cranial neural crest (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115484'],
#  'abnormal   irregular spatial pattern of somite (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115340'],
#  'abnormal   large globe (hpo)': ['http://purl.obolibrary.org/obo/HP_0001090'],
#  'abnormal   large third pharyngeal arch artery': ['http://purl.obolibrary.org/obo/MP_0030337'],
#  'abnormal   large tongue': ['http://purl.obolibrary.org/obo/HP_0000158'],
#  'abnormal   laterally curved whole organism (xpo)': ['http://purl.obolibrary.org/obo/XPO_0115507'],
#  'abnormal   lax or hyperextensible skin (hpo)': ['http://purl.obolibrary.org/obo/HP_0008067'],
#  'abnormal   localised abdominal myoblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127156'],
#  'abnormal   localised abducens nerve (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127043'],
#  'abnormal   localised absorptive cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127979'],
#  'abnormal   localised accessory nerve (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127299'],
#  'abnormal   localised accessory olfactory bulb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126322'],
#  'abnormal   localised acellular anatomical structure (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126562'],
#  'abnormal   localised acellular bone tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127497'],
#  'abnormal   localised acid secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127160'],
#  'abnormal   localised acinar cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127656'],
#  'abnormal   localised actin cytoskeleton (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131551'],
#  'abnormal   localised actin filament (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131561'],
#  'abnormal   localised adenohypophyseal placode (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126869'],
#  'abnormal   localised adenohypophysis (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127050'],
#  'abnormal   localised adherens junction (xpo)': ['http://purl.obolibrary.org/obo/XPO_0131550'],
#  'abnormal   localised adipose tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126990'],
#  'abnormal   localised adrenal cortex (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127939'],
#  'abnormal   localised adrenal gland (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127300'],
#  'abnormal   localised adrenal medulla (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127723'],
#  'abnormal   localised adult immune system (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127710'],
#  'abnormal   localised adult intestinal epithelium (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127191'],
#  'abnormal   localised adult kidney (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126885'],
#  'abnormal   localised adult thrombocyte (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127070'],
#  'abnormal   localised afferent neuron (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127386'],
#  'abnormal   localised alimentary system (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126466'],
#  'abnormal   localised alkali secreting cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127824'],
#  'abnormal   localised alpha cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127724'],
#  'abnormal   localised amacrine cell (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127623'],
#  'abnormal   localised amphibian papilla (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127629'],
#  'abnormal   localised ampullary nerve (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127841'],
#  'abnormal   localised amputated fin (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127784'],
#  'abnormal   localised amputated limb (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126881'],
#  'abnormal   localised amputated tissue (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126829'],
#  'abnormal   localised amygdala (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126687'],
#  'abnormal   localised anatomical cluster (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126414'],
#  'abnormal   localised anatomical group (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126386'],
#  'abnormal   localised anatomical line (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126624'],
#  'abnormal   localised anatomical region (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126450'],
#  'abnormal   localised anatomical space (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126372'],
#  'abnormal   localised anatomical structure (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126321'],
#  'abnormal   localised anatomical system (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126385'],
#  'abnormal   localised angioblast (xpo)': ['http://purl.obolibrary.org/obo/XPO_0127633'],
#  'abnormal   localised animal blastomere (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126833'],
#  'abnormal   localised animal cap (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126663'],
#  'abnormal   localised animal cap inner layer (xpo)': ['http://purl.obolibrary.org/obo/XPO_0126390'],
#  ...}

# %%
# This step is a complicated hack that tries to get rid of them of the false exact synonyms. 
# The idea is this: if there is an exact synonym between two terms within an ontology, we get rid of the link. 
# Sometimes, however, a synonym is shared between more than one term within and ontology and across: 
# These cases need to be

import re

def get_dupes(a):
    seen = {}
    dupes = []

    for x in a:
        if x not in seen:
            seen[x] = 1
        else:
            if seen[x] == 1:
                dupes.append(x)
            seen[x] += 1
    return dupes

cases = dict()
cases_internal = dict()
i = 0

exclude_synonyms = dict()

for label in dd:
    iris = dd.get(label)
    onts = [re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")) for iri in iris]
    if len(onts)>1:
        if len(onts) != len(set(onts)):
            if len(set(onts))>1:
                cases[label] = iris
                print("-----------------------")
                print(label)
                print(iris)
                dupes = get_dupes(onts)
                for dupe in dupes:
                    for iri in iris:
                        if dupe in iri:
                            if label not in exclude_synonyms:
                                exclude_synonyms[label]=[]
                            exclude_synonyms[label].append(iri)
            else:
                cases_internal[label] = iris
                for iri in iris:
                    if label not in exclude_synonyms:
                        exclude_synonyms[label]=[]
                    exclude_synonyms[label].append(iri)


print(len(cases_internal))
print(len(cases))
print(len(dd))
# Out:
# -----------------------
# asd
# ['http://purl.obolibrary.org/obo/HP_0000729', 'http://purl.obolibrary.org/obo/HP_0001631', 'http://purl.obolibrary.org/obo/MP_0010403']
# 6
# 1
# 174856

# %%
x = d

# %%
# Remove all those IRIs that contained duplicates determined in the previous step
d=x
print(len(d))
for label in exclude_synonyms:
    for iri in exclude_synonyms[label]:
        d = d[~((d['iri']==iri) & (d['label']==label))]
print(len(d))
d = pd.merge(d,l,on=['iri','label'],how='outer')
print(len(d))
# Out:
# 175815
# 175801
# 275738

# %%
dd=d.groupby('label')['iri'].apply(list).to_dict()

# %%
# 
def pairwise(t):
    it = iter(t)
    return zip(it,it)

def invert_dol_nonunique(d):
    newdict = {}
    for k in d:
        for v in d[k]:
            newdict.setdefault(v, []).append(k)
    return newdict

def merge_label_equivalent_cliques(dd_rv):
    merge_labels = dict()
    for iri in dd_rv:
        labels_to_merge = dd_rv.get(iri)
        if len(labels_to_merge)>1:
            for lab in labels_to_merge:
                if lab not in merge_labels:
                    merge_labels[lab] = []
                merge_labels[lab] = list(set(merge_labels[lab]+labels_to_merge))
    return merge_labels

dd_rv = invert_dol_nonunique(dd)
merge_labels = merge_label_equivalent_cliques(dd_rv)

# %%
def compute_mappings(dd,l):
    data = []
    done = set()
    for label in dd:
        if label in done:
            continue
        done.add(label)
        iris = dd.get(label)
        if label in merge_labels:
            for lab in merge_labels[label]:
                iris.extend(dd.get(lab))
                done.add(lab)
        iris = list(set(iris))
        if len(iris)>1:
            #print(iris)
            pairs = pairwise(iris)
            for pair in pairs:
                data.append([pair[0], pair[1]])
                data.append([pair[1], pair[0]])
    df_mappings =  pd.DataFrame.from_records(data)
    df_mappings = df_mappings.drop_duplicates()
    df_mappings['cat'] = 'lexical'
    df_mappings.columns = ['p1','p2','cat']
    df_maps = pd.merge(df_mappings,l,  how='left', left_on=['p1'], right_on=['iri'])
    # df_maps=df_maps.drop('iri',1)
    df_maps = pd.merge(df_maps, l,  how='left', left_on=['p2'], right_on=['iri'])
    # df_maps=df_maps.drop('iri',1)
    df_maps['o1']=[re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")) for iri in df_maps['p1'].values]
    df_maps['o2']=[re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")) for iri in df_maps['p2'].values]
    return df_maps

df_mapping = compute_mappings(dd,l)
print(len(df_mapping))
df_mapping.head()
# Out:
# 1424
#                                           p1  \
# 0  http://purl.obolibrary.org/obo/MP_0004592
# 1  http://purl.obolibrary.org/obo/HP_0000347
# 2  http://purl.obolibrary.org/obo/HP_0003270
# 3  http://purl.obolibrary.org/obo/MP_0009247
# 4  http://purl.obolibrary.org/obo/HP_0003363
#
#                                           p2      cat  \
# 0  http://purl.obolibrary.org/obo/HP_0000347  lexical
# 1  http://purl.obolibrary.org/obo/MP_0004592  lexical
# 2  http://purl.obolibrary.org/obo/MP_0009247  lexical
# 3  http://purl.obolibrary.org/obo/HP_0003270  lexical
# 4  http://purl.obolibrary.org/obo/MP_0002766  lexical
#
#                                        iri_x                         label_x  \
# 0  http://purl.obolibrary.org/obo/MP_0004592            small mandible (MPO)
# 1  http://purl.obolibrary.org/obo/HP_0000347              Micrognathia (HPO)
# 2  http://purl.obolibrary.org/obo/HP_0003270      Abdominal distention (HPO)
# 3  http://purl.obolibrary.org/obo/MP_0009247                 meteorism (MPO)
# 4  http://purl.obolibrary.org/obo/HP_0003363  Abdominal situs inversus (HPO)
#
#                                        iri_y                     label_y  o1  \
# 0  http://purl.obolibrary.org/obo/HP_0000347          Micrognathia (HPO)  MP
# 1  http://purl.obolibrary.org/obo/MP_0004592        small mandible (MPO)  HP
# 2  http://purl.obolibrary.org/obo/MP_0009247             meteorism (MPO)  HP
# 3  http://purl.obolibrary.org/obo/HP_0003270  Abdominal distention (HPO)  MP
# 4  http://purl.obolibrary.org/obo/MP_0002766        situs inversus (MPO)  HP
#
#    o2
# 0  HP
# 1  MP
# 2  MP
# 3  HP
# 4  MP
